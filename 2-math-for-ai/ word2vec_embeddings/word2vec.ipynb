# %%
import os
from sentence_transformers import SentenceTransformer

words = ["king", "queen", "car"]
vectors = model.encode(words)

similarity_king_queen = model.similarity(vectors[0], vectors[1])
similarity_king_car = model.similarity(vectors[0], vectors[2])

print(f"Similarity between 'king' and 'queen': {similarity_king_queen.item():.4f}")
print(f"Similarity between 'king' and 'car':   {similarity_king_car.item():.4f}")
# Out:
# Similarity between 'king' and 'queen': 0.6807
# Similarity between 'king' and 'car':   0.2876
