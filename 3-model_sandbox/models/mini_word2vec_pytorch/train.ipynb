# %%
import torch
import torch.nn as nn

# %%
word = ["men", "women", "car", "train", "stylo", "crayon", "red", "blue"]
word_idx = {"men": 0, "women": 1, "car": 2, "train": 3, "stylo": 4, "crayon": 5, "red": 6, "blue": 7}
pair_tuple = ((0, 1), (2, 3), (4, 5), (6, 7))

tensor = torch.tensor(pair_tuple)
enbedding_layer = nn.Embedding(8, 2)
enbedding_layer(tensor)
# Out:
# tensor([[[ 1.7160, -1.0633],
#          [-1.7979, -0.5871]],
#
#         [[ 1.4639, -0.4520],
#          [ 0.5324, -0.3275]],
#
#         [[-0.5957,  0.7575],
#          [ 0.5372, -1.5515]],
#
#         [[-1.7407,  0.1516],
#          [-0.9268,  0.8585]]], grad_fn=<EmbeddingBackward0>)
